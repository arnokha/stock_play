# %% [markdown]
# ## Goal of this notebook
#  - Plot KDE (kernel density estimate) of distributions after each two day movement category combination
#  - Take a look at the mean, variance, and level of normality of these curves

# %%
from stock_utils import *

# %%
df = pd.DataFrame()
df = df.from_csv('stock_data/spy.csv')
daily_movements = get_price_movement_percentages(df)
movement_categories = categorize_movements(daily_movements)
three_day_trends_linear = get_trends_linear(movement_categories, daily_movements, 3)

# %%
all_cats = ['bd', 'sd', 'sg', 'bg']
movements_after_category = []
for cat1 in all_cats:
    for cat2 in all_cats:
        movements_after_category.append(get_movements_after_trend(cat1 + '_' + cat2, three_day_trends_linear))

# %%
## Big drop on the first day

plt.figure(figsize=(16,8))
plt.subplot(2, 2, 1)
x = movements_after_category[0]
n = len(movements_after_category[0])
plot_gaussian_categorical(x, title="Distribution of Movements after 2 Big Drops", n_cats=4, n_data=n)

plt.subplot(2, 2, 2)
x = movements_after_category[1]
n = len(movements_after_category[1])
plot_gaussian_categorical(x, title="Distribution of Movements after a Big Drop, then a Small Drop", n_cats=4, n_data=n)

plt.subplot(2, 2, 3)
x = movements_after_category[2]
n = len(movements_after_category[2])
plot_gaussian_categorical(x, title="Distribution of Movements after a Big Drop, then a Small Gain", n_cats=4, n_data=n)

plt.subplot(2, 2, 4)
x = movements_after_category[3]
n = len(movements_after_category[3])
plot_gaussian_categorical(x, title="Distribution of Movements after a Big Drop, then a Big Gain", n_cats=4, n_data=n)

plt.tight_layout()
plt.show()

# %%
## Small drop on the first day

plt.figure(figsize=(16,8))
plt.subplot(2, 2, 1)
x = movements_after_category[4]
n = len(movements_after_category[4])
plot_gaussian_categorical(x, title="Distribution of Movements after a Small Drop, then a Big Drop", n_cats=4, n_data=n)

plt.subplot(2, 2, 2)
x = movements_after_category[5]
n = len(movements_after_category[5])
plot_gaussian_categorical(x, title="Distribution of Movements after 2 Small Drops", n_cats=4, n_data=n)

plt.subplot(2, 2, 3)
x = movements_after_category[6]
n = len(movements_after_category[6])
plot_gaussian_categorical(x, title="Distribution of Movements after a Small Drop, then a Small Gain", n_cats=4, n_data=n)

plt.subplot(2, 2, 4)
x = movements_after_category[7]
n = len(movements_after_category[7])
plot_gaussian_categorical(x, title="Distribution of Movements after a Small Drop, then a Big Gain", n_cats=4, n_data=n)

plt.tight_layout()
plt.show()

# %%
## Small gain on the first day

plt.figure(figsize=(16,8))
plt.subplot(2, 2, 1)
x = movements_after_category[8]
n = len(movements_after_category[8])
plot_gaussian_categorical(x, title="Distribution of Movements after a Small Gain, then a Big Drop", n_cats=4, n_data=n)

plt.subplot(2, 2, 2)
x = movements_after_category[9]
n = len(movements_after_category[9])
plot_gaussian_categorical(x, title="Distribution of Movements after a Small Gain, then a Small Drop", n_cats=4, n_data=n)

plt.subplot(2, 2, 3)
x = movements_after_category[10]
n = len(movements_after_category[10])
plot_gaussian_categorical(x, title="Distribution of Movements after 2 Small Gains", n_cats=4, n_data=n)

plt.subplot(2, 2, 4)
x = movements_after_category[11]
n = len(movements_after_category[11])
plot_gaussian_categorical(x, title="Distribution of Movements after a Small Gain, then a Big Gain", n_cats=4, n_data=n)

plt.tight_layout()
plt.show()

# %%
## Big gain on the first day

plt.figure(figsize=(16,8))
plt.subplot(2, 2, 1)
x = movements_after_category[12]
n = len(movements_after_category[12])
plot_gaussian_categorical(x, title="Distribution of Movements after a Big Gain, then a Big Drop", n_cats=4, n_data=n)

plt.subplot(2, 2, 2)
x = movements_after_category[13]
n = len(movements_after_category[13])
plot_gaussian_categorical(x, title="Distribution of Movements after a Big Gain, then a Small Drop", n_cats=4, n_data=n)

plt.subplot(2, 2, 3)
x = movements_after_category[14]
n = len(movements_after_category[14])
plot_gaussian_categorical(x, title="Distribution of Movements after a Big Gain, then a Small Gain", n_cats=4, n_data=n)

plt.subplot(2, 2, 4)
x = movements_after_category[15]
n = len(movements_after_category[15])
plot_gaussian_categorical(x, title="Distribution of Movements after 2 Big Gains", n_cats=4, n_data=n)

plt.tight_layout()
plt.show()

# %% [markdown]
# # All Stocks

# %%
g = glob.glob('stock_data/*.csv')
all_cats = ['bd', 'sd', 'sg', 'bg']

for filename in g:
    df = pd.DataFrame()
    df = df.from_csv(filename)
    daily_movements = get_price_movement_percentages(df)
    movement_categories = categorize_movements(daily_movements)
    three_day_trends_linear = get_trends_linear(movement_categories, daily_movements, 3)
    ticker = ticker_from_csv(filename)
    
    all_cats = ['bd', 'sd', 'sg', 'bg']
    movements_after_category = []
    for cat1 in all_cats:
        for cat2 in all_cats:
            movements_after_category.append(get_movements_after_trend(cat1 + '_' + cat2, three_day_trends_linear))

    print('=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=')
    print('                                      ' + ticker)
    print('=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=')
    print()
    print()
    ## Big drop on the first day
    plt.figure(figsize=(16,8))
    plt.subplot(2, 2, 1)
    x = movements_after_category[0]
    n = len(movements_after_category[0])
    plot_gaussian_categorical(x, title="Distribution of Movements after 2 Big Drops", n_cats=4, n_data=n, x_min=-15, x_max=15)
    plt.subplot(2, 2, 2)
    x = movements_after_category[1]
    n = len(movements_after_category[1])
    plot_gaussian_categorical(x, title="Distribution of Movements after a Big Drop, then a Small Drop", n_cats=4, n_data=n, x_min=-15, x_max=15)
    plt.subplot(2, 2, 3)
    x = movements_after_category[2]
    n = len(movements_after_category[2])
    plot_gaussian_categorical(x, title="Distribution of Movements after a Big Drop, then a Small Gain", n_cats=4, n_data=n, x_min=-15, x_max=15)
    plt.subplot(2, 2, 4)
    x = movements_after_category[3]
    n = len(movements_after_category[3])
    plot_gaussian_categorical(x, title="Distribution of Movements after a Big Drop, then a Big Gain", n_cats=4, n_data=n, x_min=-15, x_max=15)
    plt.tight_layout()
    plt.show()
    
    ## Small drop on the first day
    plt.figure(figsize=(16,8))
    plt.subplot(2, 2, 1)
    x = movements_after_category[4]
    n = len(movements_after_category[4])
    plot_gaussian_categorical(x, title="Distribution of Movements after a Small Drop, then a Big Drop", n_cats=4, n_data=n, x_min=-15, x_max=15)
    plt.subplot(2, 2, 2)
    x = movements_after_category[5]
    n = len(movements_after_category[5])
    plot_gaussian_categorical(x, title="Distribution of Movements after 2 Small Drops", n_cats=4, n_data=n, x_min=-15, x_max=15)
    plt.subplot(2, 2, 3)
    x = movements_after_category[6]
    n = len(movements_after_category[6])
    plot_gaussian_categorical(x, title="Distribution of Movements after a Small Drop, then a Small Gain", n_cats=4, n_data=n, x_min=-15, x_max=15)
    plt.subplot(2, 2, 4)
    x = movements_after_category[7]
    n = len(movements_after_category[7])
    plot_gaussian_categorical(x, title="Distribution of Movements after a Small Drop, then a Big Gain", n_cats=4, n_data=n, x_min=-15, x_max=15)
    plt.tight_layout()
    plt.show()
    
    ## Small gain on the first day
    plt.figure(figsize=(16,8))
    plt.subplot(2, 2, 1)
    x = movements_after_category[8]
    n = len(movements_after_category[8])
    plot_gaussian_categorical(x, title="Distribution of Movements after a Small Gain, then a Big Drop", n_cats=4, n_data=n, x_min=-15, x_max=15)
    plt.subplot(2, 2, 2)
    x = movements_after_category[9]
    n = len(movements_after_category[9])
    plot_gaussian_categorical(x, title="Distribution of Movements after a Small Gain, then a Small Drop", n_cats=4, n_data=n, x_min=-15, x_max=15)
    plt.subplot(2, 2, 3)
    x = movements_after_category[10]
    n = len(movements_after_category[10])
    plot_gaussian_categorical(x, title="Distribution of Movements after 2 Small Gains", n_cats=4, n_data=n, x_min=-15, x_max=15)
    plt.subplot(2, 2, 4)
    x = movements_after_category[11]
    n = len(movements_after_category[11])
    plot_gaussian_categorical(x, title="Distribution of Movements after a Small Gain, then a Big Gain", n_cats=4, n_data=n, x_min=-15, x_max=15)
    plt.tight_layout()
    plt.show()
    
    ## Big gain on the first day
    plt.figure(figsize=(16,8))
    plt.subplot(2, 2, 1)
    x = movements_after_category[12]
    n = len(movements_after_category[12])
    plot_gaussian_categorical(x, title="Distribution of Movements after a Big Gain, then a Big Drop", n_cats=4, n_data=n, x_min=-15, x_max=15)
    plt.subplot(2, 2, 2)
    x = movements_after_category[13]
    n = len(movements_after_category[13])
    plot_gaussian_categorical(x, title="Distribution of Movements after a Big Gain, then a Small Drop", n_cats=4, n_data=n, x_min=-15, x_max=15)
    plt.subplot(2, 2, 3)
    x = movements_after_category[14]
    n = len(movements_after_category[14])
    plot_gaussian_categorical(x, title="Distribution of Movements after a Big Gain, then a Small Gain", n_cats=4, n_data=n, x_min=-15, x_max=15)
    plt.subplot(2, 2, 4)
    x = movements_after_category[15]
    n = len(movements_after_category[15])
    plot_gaussian_categorical(x, title="Distribution of Movements after 2 Big Gains", n_cats=4, n_data=n, x_min=-15, x_max=15)
    plt.tight_layout()
    plt.show()
    print()
    print()
# Out:
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#                                       BAC
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#                                       NVDA
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#                                       NKE
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#                                       SBUX
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# ...
