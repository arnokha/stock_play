# %% [markdown]
# ## Goal of this notebook
# Build composite models for two week momentum, three week momentum, two month momentum, three month momentum, volume, and intra-day range

# %%
from stock_utils import *

# %%
df = pd.DataFrame()
df = df.from_csv('stock_data/nvda.csv')

weekly_movements = get_price_movements(df, period=7)
weekly_movement_categories = categorize_movements(weekly_movements, n_cats=4)
monthly_movements = get_price_movements(df, period=30)
monthly_movement_categories = categorize_movements(monthly_movements, n_cats=4)

two_week_movement_trends = get_trends(weekly_movement_categories, 2)
three_week_movement_trends = get_trends(weekly_movement_categories, 3)
two_month_movement_trends = get_trends(monthly_movement_categories, 2)
three_month_movement_trends = get_trends(monthly_movement_categories, 3)

movement_category_types = ['bd', 'sd', 'sg', 'bg']

# %%
local_two_week_probs = build_model_probabilities(weekly_movement_categories, two_week_movement_trends, 2)
local_one_week_probs = build_model_probabilities(weekly_movement_categories, [], 1)

local_two_month_probs = build_model_probabilities(monthly_movement_categories, two_month_movement_trends, 2)
local_one_month_probs = build_model_probabilities(monthly_movement_categories, [], 1)

# %% [markdown]
# ## Local 1 week model v.s. Local 2 week model

# %%
m1_wins, m2_wins, n_draws = \
    random_sample_tests_m1_m2(weekly_movement_categories, local_one_week_probs, 1, local_two_week_probs, 2, sample_size=20)
    
print('Local one week model won ' + str(m1_wins) + ' times')
print('Local two week model won ' + str(m2_wins) + ' times')
# Out:
# Local one week model won 4812 times
# Local two week model won 4677 times

# %% [markdown]
# ## Composite 1 week model v.s. Composite 2 week model

# %%
all_two_week_trends, _, composite_one_week_probs, all_weekly_movement_categories = \
    get_trends_all_stocks(7, 2, movement_category_types, n_cats=4)

composite_two_week_probs = build_model_probabilities(all_weekly_movement_categories, all_two_week_trends, 2)

# %%
m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(weekly_movement_categories, composite_one_week_probs, 
                                                      1, composite_two_week_probs, 2, sample_size=20)

print('Composite one week model won ' + str(m1_wins) + ' times')
print('Composite two week model won ' + str(m2_wins) + ' times')
# Out:
# Composite one week model won 327 times
# Composite two week model won 9218 times

# %% [markdown]
# ## Local 2 week model v.s. Composite 2 week model
# Likely overfit

# %%
m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(weekly_movement_categories, local_two_week_probs, 
                                                      2, composite_two_week_probs, 2, sample_size=20)

print('Local two week model won ' + str(m1_wins) + ' times')
print('Composite two week model won ' + str(m2_wins) + ' times')
# Out:
# Local two week model won 9033 times
# Composite two week model won 805 times

# %% [markdown]
# ## Composite 2 week model v.s. Composite 3 week model

# %%
all_three_week_trends, _, _, _ = get_trends_all_stocks(7, 3, movement_category_types, n_cats=4)

composite_three_week_probs = build_model_probabilities(all_weekly_movement_categories, all_three_week_trends, 3)

# %%
m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(weekly_movement_categories, composite_two_week_probs, 
                                                      2, composite_three_week_probs, 3, sample_size=25)

print('Composite two week model won ' + str(m1_wins) + ' times')
print('Composite three week model won ' + str(m2_wins) + ' times')
# Out:
# Composite two week model won 2518 times
# Composite three week model won 7121 times

# %% [markdown]
# ## Composite 1 month model v.s. Composite 2 month model

# %%
all_two_month_trends, _, composite_one_month_probs, all_monthly_movement_categories = \
    get_trends_all_stocks(30, 2, movement_category_types, n_cats=4)

composite_two_month_probs = build_model_probabilities(all_monthly_movement_categories, all_two_month_trends, 2)

# %%
m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(monthly_movement_categories, composite_one_month_probs, 
                                                      1, composite_two_month_probs, 2, sample_size=10)

print('Composite one month model won ' + str(m1_wins) + ' times')
print('Composite two month model won ' + str(m2_wins) + ' times')
# Out:
# Composite one month model won 5999 times
# Composite two month model won 2219 times

# %% [markdown]
# ## Composite 2 month model v.s. Composite 3 month model

# %%
all_three_month_trends, _, _, _ = get_trends_all_stocks(30, 3, movement_category_types, n_cats=4)

composite_three_month_probs = build_model_probabilities(all_monthly_movement_categories, all_three_month_trends, 3)

# %%
m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(monthly_movement_categories, composite_two_month_probs, 
                                                      2, composite_three_month_probs, 3, sample_size=10)

print('Composite two month model won ' + str(m1_wins) + ' times')
print('Composite three month model won ' + str(m2_wins) + ' times')
# Out:
# Composite two month model won 1492 times
# Composite three month model won 7941 times

# %% [markdown]
# ## Composite 1 month model v.s. Composite 3 month model

# %%
m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(monthly_movement_categories, composite_one_month_probs, 
                                                      1, composite_three_month_probs, 3, sample_size=10)

print('Composite one month model won ' + str(m1_wins) + ' times')
print('Composite three month model won ' + str(m2_wins) + ' times')
# Out:
# Composite one month model won 1402 times
# Composite three month model won 8476 times

# %% [markdown]
# # All Stocks

# %%
g = glob.glob('stock_data/*.csv')

# %%
## Get composite weekly probabilities
all_two_week_trends, _, composite_one_week_probs, all_weekly_movement_categories = \
    get_trends_all_stocks(7, 2, movement_category_types, n_cats=4)
all_three_week_trends, _, _, _ = get_trends_all_stocks(7, 3, movement_category_types, n_cats=4)
composite_two_week_probs = build_model_probabilities(all_weekly_movement_categories, all_two_week_trends, 2)
composite_three_week_probs = build_model_probabilities(all_weekly_movement_categories, all_three_week_trends, 3)

## Get composite monthly probabilities
all_two_month_trends, _, composite_one_month_probs, all_monthly_movement_categories = \
    get_trends_all_stocks(30, 2, movement_category_types, n_cats=4)
all_three_month_trends, _, _, _ = get_trends_all_stocks(30, 3, movement_category_types, n_cats=4)
composite_two_month_probs = build_model_probabilities(all_monthly_movement_categories, all_two_month_trends, 2)
composite_three_month_probs = build_model_probabilities(all_monthly_movement_categories, all_three_month_trends, 3)

for filename in g:
    ticker = ticker_from_csv(filename)
    df = pd.DataFrame()
    df = df.from_csv(filename)
    weekly_movements = get_price_movements(df, period=7)
    weekly_movement_categories = categorize_movements(weekly_movements, n_cats=4)
    monthly_movements = get_price_movements(df, period=30)
    monthly_movement_categories = categorize_movements(monthly_movements, n_cats=4)

    two_week_movement_trends = get_trends(weekly_movement_categories, 2)
    three_week_movement_trends = get_trends(weekly_movement_categories, 3)
    two_month_movement_trends = get_trends(monthly_movement_categories, 2)
    three_month_movement_trends = get_trends(monthly_movement_categories, 3)

    local_two_week_probs = build_model_probabilities(weekly_movement_categories, two_week_movement_trends, 2)
    local_one_week_probs = build_model_probabilities(weekly_movement_categories, [], 1)
    local_two_month_probs = build_model_probabilities(monthly_movement_categories, two_month_movement_trends, 2)
    local_one_month_probs = build_model_probabilities(monthly_movement_categories, [], 1)
    
    print('=-=-=-=-=-=-=-=-=-=-=-=-=-=-=')
    print('             ' + ticker)
    print('=-=-=-=-=-=-=-=-=-=-=-=-=-=-=')
    print()
    
    print('--------------------------------------------------')
    print('Local 1 week model v.s. Local 2 week model')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = \
      random_sample_tests_m1_m2(weekly_movement_categories, local_one_week_probs, 1, local_two_week_probs, 2, sample_size=20)
    
    print('Local one week model won ' + str(m1_wins) + ' times')
    print('Local two week model won ' + str(m2_wins) + ' times')
    print()
    
    print('--------------------------------------------------')
    print('Composite 1 week model v.s. Composite 2 week model')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(weekly_movement_categories, composite_one_week_probs, 
                                                      1, composite_two_week_probs, 2, sample_size=20)

    print('Composite one week model won ' + str(m1_wins) + ' times')
    print('Composite two week model won ' + str(m2_wins) + ' times')
    print()
    
    print('--------------------------------------------------')
    print('Local 2 week model v.s. Composite 2 week model')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(weekly_movement_categories, local_two_week_probs, 
                                                      2, composite_two_week_probs, 2, sample_size=20)

    print('Local two week model won ' + str(m1_wins) + ' times')
    print('Composite two week model won ' + str(m2_wins) + ' times')
    print()
    
    print('--------------------------------------------------')
    print('Composite 2 week model v.s. Composite 3 week model')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(weekly_movement_categories, composite_two_week_probs, 
                                                      2, composite_three_week_probs, 3, sample_size=25)

    print('Composite two week model won ' + str(m1_wins) + ' times')
    print('Composite three week model won ' + str(m2_wins) + ' times')
    print()
    
    print('--------------------------------------------------')
    print('Composite 1 month model v.s. Composite 2 month model')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(monthly_movement_categories, composite_one_month_probs, 
                                                      1, composite_two_month_probs, 2, sample_size=10)

    print('Composite one month model won ' + str(m1_wins) + ' times')
    print('Composite two month model won ' + str(m2_wins) + ' times')
    print()

    print('--------------------------------------------------')
    print('Composite 2 month model v.s. Composite 3 month model')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(monthly_movement_categories, composite_two_month_probs, 
                                                      2, composite_three_month_probs, 3, sample_size=10)

    print('Composite two month model won ' + str(m1_wins) + ' times')
    print('Composite three month model won ' + str(m2_wins) + ' times')
    print()
    
    print('--------------------------------------------------')
    print('Composite 1 month model v.s. Composite 3 month model')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(monthly_movement_categories, composite_one_month_probs, 
                                                      1, composite_three_month_probs, 3, sample_size=10)

    print('Composite one month model won ' + str(m1_wins) + ' times')
    print('Composite three month model won ' + str(m2_wins) + ' times')
    print()
    
    print()
# Out:
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              BAC
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 778 times
# Local two week model won 8964 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 182 times
# Composite two week model won 9793 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 10000 times
# Composite two week model won 0 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 219 times
# Composite three week model won 9595 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 5590 times
# Composite two month model won 3628 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 404 times
# Composite three month model won 8484 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 143 times
# Composite three month model won 9021 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              NVDA
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 4812 times
# Local two week model won 4703 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 298 times
# Composite two week model won 9258 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 9031 times
# Composite two week model won 820 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 2433 times
# Composite three week model won 7231 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 6090 times
# Composite two month model won 2133 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 1518 times
# Composite three month model won 7978 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 1424 times
# Composite three month model won 8446 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              NKE
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 2217 times
# Local two week model won 7394 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 638 times
# Composite two week model won 8896 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 4243 times
# Composite two week model won 4983 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 1482 times
# Composite three week model won 7804 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 9005 times
# Composite two month model won 381 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 1515 times
# Composite three month model won 7787 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 1145 times
# Composite three month model won 7908 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              SBUX
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 906 times
# Local two week model won 8776 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 958 times
# Composite two week model won 8994 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 6605 times
# Composite two week model won 3022 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 1244 times
# Composite three week model won 8412 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 6397 times
# Composite two month model won 2056 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 1092 times
# Composite three month model won 8771 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 949 times
# Composite three month model won 8916 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              AMD
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 4282 times
# Local two week model won 5153 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 998 times
# Composite two week model won 8804 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 7842 times
# Composite two week model won 1638 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 1775 times
# Composite three week model won 7680 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 8192 times
# Composite two month model won 1364 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 2758 times
# Composite three month model won 6693 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 1643 times
# Composite three month model won 7800 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              MU
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 2001 times
# Local two week model won 7553 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 518 times
# Composite two week model won 9359 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 8694 times
# Composite two week model won 1084 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 1785 times
# Composite three week model won 7669 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 8760 times
# Composite two month model won 1110 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 1407 times
# Composite three month model won 8062 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 1171 times
# Composite three month model won 8285 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              SPY
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 0 times
# Local two week model won 10000 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 382 times
# Composite two week model won 9596 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 8103 times
# Composite two week model won 1537 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 1644 times
# Composite three week model won 8103 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 4502 times
# Composite two month model won 3573 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 888 times
# Composite three month model won 8988 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 426 times
# Composite three month model won 9316 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              GOOG
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 4306 times
# Local two week model won 5421 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 1915 times
# Composite two week model won 7784 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 5476 times
# Composite two week model won 4335 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 924 times
# Composite three week model won 8667 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 10000 times
# Composite two month model won 0 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 4424 times
# Composite three month model won 5576 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 4370 times
# Composite three month model won 5630 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              TSLA
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 2458 times
# Local two week model won 7162 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 1963 times
# Composite two week model won 7799 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 2550 times
# Composite two week model won 6930 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 1206 times
# Composite three week model won 7886 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 9395 times
# Composite two month model won 401 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 4215 times
# Composite three month model won 4237 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 2778 times
# Composite three month model won 4740 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              FB
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 2875 times
# Local two week model won 6399 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 0 times
# Composite two week model won 10000 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 8081 times
# Composite two week model won 1499 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 2969 times
# Composite three week model won 6481 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 4394 times
# Composite two month model won 5606 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 624 times
# Composite three month model won 9045 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 570 times
# Composite three month model won 9150 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              INTC
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 2634 times
# Local two week model won 6584 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 2031 times
# Composite two week model won 7750 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 9157 times
# Composite two week model won 706 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 3412 times
# Composite three week model won 6031 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 5908 times
# Composite two month model won 3303 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 1770 times
# Composite three month model won 7562 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 2067 times
# Composite three month model won 7662 times

# %% [markdown]
# # Volume Models

# %%
df = pd.DataFrame()
df = df.from_csv('stock_data/nvda.csv')

daily_rel_volumes_25 = get_relative_volume(df, relative_period=25)
daily_rel_volumes_50 = get_relative_volume(df, relative_period=50)
daily_rel_volume_categories_25 = categorize_volumes(daily_rel_volumes_25)
daily_rel_volume_categories_50 = categorize_volumes(daily_rel_volumes_50)

daily_movements = get_price_movements(df)
daily_movement_categories = categorize_movements(daily_movements, n_cats=4)

# %%
local_two_day_vol_trends_25 = get_two_day_volume_trends(daily_rel_volume_categories_25, daily_movement_categories)
local_two_day_vol_trends_50 = get_two_day_volume_trends(daily_rel_volume_categories_50, daily_movement_categories)

local_two_day_probs_25 = build_model_probabilities(daily_movement_categories, local_two_day_vol_trends_25, 2, 
                                               previous_category_types=['vl', 'l', 'h', 'vh'])
local_two_day_probs_50 = build_model_probabilities(daily_movement_categories, local_two_day_vol_trends_50, 2, 
                                               previous_category_types=['vl', 'l', 'h', 'vh'])

# %% [markdown]
# ## Local 2 day Relative Volume Model: RP=25 v.s. RP=50

# %%
m1_wins, m2_wins, n_draws = \
    random_sample_tests_m1_m2(daily_movement_categories, local_two_day_probs_25, 2, local_two_day_probs_50, 2)
    
print('RP=25 won ' + str(m1_wins) + ' times')
print('RP=50 won ' + str(m2_wins) + ' times')
# Out:
# RP=25 won 7399 times
# RP=50 won 2400 times

# %% [markdown]
# #### All stocks -- Local
# The sweet spot seems to be about a 20 day relative window

# %%
all_two_day_volume_trends, _, _, _ = get_volume_trends_all_stocks(1, ['vl', 'l', 'h', 'vh'], relative_period=20)
_, _, _, all_movement_categories = get_trends_all_stocks(1, 2, ['bd', 'sd', 'sg', 'bg'])

composite_two_day_probs_20 = build_model_probabilities(all_movement_categories, all_two_day_volume_trends, 
                                                           2, previous_category_types=['vl', 'l', 'h', 'vh'])

for filename in g:
    ticker = ticker_from_csv(filename)
    df = pd.DataFrame()
    df = df.from_csv(filename)
    
    daily_rel_volumes_10 = get_relative_volume(df, relative_period=10)
    daily_rel_volumes_20 = get_relative_volume(df, relative_period=20)
    daily_rel_volumes_30 = get_relative_volume(df, relative_period=30)
    daily_rel_volumes_40 = get_relative_volume(df, relative_period=40)
    daily_rel_volumes_50 = get_relative_volume(df, relative_period=50)
    daily_rel_volume_categories_10 = categorize_volumes(daily_rel_volumes_10)
    daily_rel_volume_categories_20 = categorize_volumes(daily_rel_volumes_20)
    daily_rel_volume_categories_30 = categorize_volumes(daily_rel_volumes_30)
    daily_rel_volume_categories_40 = categorize_volumes(daily_rel_volumes_40)
    daily_rel_volume_categories_50 = categorize_volumes(daily_rel_volumes_50)
    
    daily_movements = get_price_movements(df)
    daily_movement_categories = categorize_movements(daily_movements, n_cats=4)
    
    local_two_day_vol_trends_10 = get_two_day_volume_trends(daily_rel_volume_categories_10, daily_movement_categories)
    local_two_day_vol_trends_20 = get_two_day_volume_trends(daily_rel_volume_categories_20, daily_movement_categories)
    local_two_day_vol_trends_30 = get_two_day_volume_trends(daily_rel_volume_categories_30, daily_movement_categories)
    local_two_day_vol_trends_40 = get_two_day_volume_trends(daily_rel_volume_categories_40, daily_movement_categories)
    local_two_day_vol_trends_50 = get_two_day_volume_trends(daily_rel_volume_categories_50, daily_movement_categories)
    
    local_two_day_probs_10 = build_model_probabilities(daily_movement_categories, local_two_day_vol_trends_10, 2, 
                                               previous_category_types=['vl', 'l', 'h', 'vh'])
    local_two_day_probs_20 = build_model_probabilities(daily_movement_categories, local_two_day_vol_trends_20, 2, 
                                               previous_category_types=['vl', 'l', 'h', 'vh'])
    local_two_day_probs_30 = build_model_probabilities(daily_movement_categories, local_two_day_vol_trends_30, 2, 
                                               previous_category_types=['vl', 'l', 'h', 'vh'])
    local_two_day_probs_40 = build_model_probabilities(daily_movement_categories, local_two_day_vol_trends_40, 2, 
                                               previous_category_types=['vl', 'l', 'h', 'vh'])
    local_two_day_probs_50 = build_model_probabilities(daily_movement_categories, local_two_day_vol_trends_50, 2, 
                                               previous_category_types=['vl', 'l', 'h', 'vh'])
    
    m1_wins, m2_wins, n_draws = \
    random_sample_tests_m1_m2(daily_movement_categories, local_two_day_probs_25, 2, local_two_day_probs_50, 2)
    
    print('=-=-=-=-=-=-=-=-=-=-=-=-=-=-=')
    print('             ' + ticker)
    print('=-=-=-=-=-=-=-=-=-=-=-=-=-=-=')
    print()
    print('--------------------------------------------------')
    print('Local 2 day Relative Volume Model: RP=10 v.s. RP=20')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = \
    random_sample_tests_m1_m2(daily_movement_categories, local_two_day_probs_10, 2, local_two_day_probs_20, 2)
    print('RP=10 won ' + str(m1_wins) + ' times')
    print('RP=20 won ' + str(m2_wins) + ' times')
    print()
    print('--------------------------------------------------')
    print('Local 2 day Relative Volume Model: RP=20 v.s. RP=30')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = \
    random_sample_tests_m1_m2(daily_movement_categories, local_two_day_probs_20, 2, local_two_day_probs_30, 2)
    print('RP=20 won ' + str(m1_wins) + ' times')
    print('RP=30 won ' + str(m2_wins) + ' times')
    print()
    print('--------------------------------------------------')
    print('Local 2 day Relative Volume Model: RP=30 v.s. RP=40')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = \
    random_sample_tests_m1_m2(daily_movement_categories, local_two_day_probs_30, 2, local_two_day_probs_40, 2)
    print('RP=30 won ' + str(m1_wins) + ' times')
    print('RP=40 won ' + str(m2_wins) + ' times')
    print()
    print('--------------------------------------------------')
    print('Local 2 day Relative Volume Model: RP=40 v.s. RP=50')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = \
    random_sample_tests_m1_m2(daily_movement_categories, local_two_day_probs_40, 2, local_two_day_probs_50, 2)
    print('RP=40 won ' + str(m1_wins) + ' times')
    print('RP=50 won ' + str(m2_wins) + ' times')
    print()
    print('--------------------------------------------------')
    print('Local 2 day Relative Volume Model vs Composite: RP=20')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = \
    random_sample_tests_m1_m2(daily_movement_categories, local_two_day_probs_20, 2, composite_two_day_probs_20, 2)
    print('Local won ' + str(m1_wins) + ' times')
    print('Composite won ' + str(m2_wins) + ' times')
    print()
    print()
# Out:
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              BAC
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 8149 times
# RP=20 won 1733 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 9362 times
# RP=30 won 558 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 6781 times
# RP=40 won 2868 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 1918 times
# RP=50 won 7783 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model vs Composite: RP=20
# --------------------------------------------------
# Local won 8772 times
# Composite won 1216 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              NVDA
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 1709 times
# RP=20 won 8100 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 9373 times
# RP=30 won 582 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 7395 times
# RP=40 won 2118 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 6182 times
# RP=50 won 3301 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model vs Composite: RP=20
# --------------------------------------------------
# Local won 199 times
# Composite won 9763 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              NKE
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 4773 times
# RP=20 won 4781 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 7044 times
# RP=30 won 2564 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 6604 times
# RP=40 won 3161 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 5141 times
# RP=50 won 4330 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model vs Composite: RP=20
# --------------------------------------------------
# Local won 4658 times
# Composite won 4862 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              SBUX
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 8194 times
# RP=20 won 1636 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 3967 times
# RP=30 won 5820 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 647 times
# RP=40 won 9280 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 8459 times
# RP=50 won 1436 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model vs Composite: RP=20
# --------------------------------------------------
# Local won 2519 times
# Composite won 7347 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              AMD
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 972 times
# RP=20 won 8899 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 8126 times
# RP=30 won 1534 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 10000 times
# RP=40 won 0 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 7359 times
# RP=50 won 2307 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model vs Composite: RP=20
# --------------------------------------------------
# Local won 8251 times
# Composite won 1546 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              MU
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 634 times
# RP=20 won 9336 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 352 times
# RP=30 won 9542 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 7174 times
# RP=40 won 2543 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 908 times
# RP=50 won 8859 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model vs Composite: RP=20
# --------------------------------------------------
# Local won 3746 times
# Composite won 5974 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              SPY
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 733 times
# RP=20 won 9144 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 8830 times
# RP=30 won 1013 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 2260 times
# RP=40 won 7546 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 5753 times
# RP=50 won 3931 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model vs Composite: RP=20
# --------------------------------------------------
# Local won 6344 times
# Composite won 3193 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              GOOG
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 7647 times
# RP=20 won 1906 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 5523 times
# RP=30 won 4189 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 6596 times
# RP=40 won 2883 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 2478 times
# RP=50 won 6985 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model vs Composite: RP=20
# --------------------------------------------------
# Local won 651 times
# Composite won 9232 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              TSLA
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 1975 times
# RP=20 won 7676 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 5484 times
# RP=30 won 4087 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 8354 times
# RP=40 won 1375 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 1795 times
# RP=50 won 7908 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model vs Composite: RP=20
# --------------------------------------------------
# Local won 9998 times
# Composite won 0 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              FB
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 1609 times
# RP=20 won 8178 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 7361 times
# RP=30 won 2415 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 1884 times
# RP=40 won 8018 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 926 times
# RP=50 won 8995 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model vs Composite: RP=20
# --------------------------------------------------
# Local won 8269 times
# Composite won 1605 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              INTC
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 2321 times
# RP=20 won 7531 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 8653 times
# RP=30 won 1202 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 878 times
# RP=40 won 8971 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 9350 times
# RP=50 won 617 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model vs Composite: RP=20
# --------------------------------------------------
# Local won 8514 times
# Composite won 1155 times
