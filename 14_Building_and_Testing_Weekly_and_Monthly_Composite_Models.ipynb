# %% [markdown]
# ## Goal of this notebook
# Build composite models for two week momentum, three week momentum, two month momentum, three month momentum, volume, and intra-day range

# %%
from stock_utils import *

# %%
df = pd.DataFrame()
df = df.from_csv('stock_data/nvda.csv')

weekly_movements = get_price_movements(df, period=7)
weekly_movement_categories = categorize_movements(weekly_movements, n_cats=4)
monthly_movements = get_price_movements(df, period=30)
monthly_movement_categories = categorize_movements(monthly_movements, n_cats=4)

two_week_movement_trends = get_trends(weekly_movement_categories, 2)
three_week_movement_trends = get_trends(weekly_movement_categories, 3)
two_month_movement_trends = get_trends(monthly_movement_categories, 2)
three_month_movement_trends = get_trends(monthly_movement_categories, 3)

movement_category_types = ['bd', 'sd', 'sg', 'bg']

# %%
local_two_week_probs = build_model_probabilities(weekly_movement_categories, two_week_movement_trends, 2)
local_one_week_probs = build_model_probabilities(weekly_movement_categories, [], 1)

local_two_month_probs = build_model_probabilities(monthly_movement_categories, two_month_movement_trends, 2)
local_one_month_probs = build_model_probabilities(monthly_movement_categories, [], 1)

# %% [markdown]
# ## Local 1 week model v.s. Local 2 week model

# %%
m1_wins, m2_wins, n_draws = \
    random_sample_tests_m1_m2(weekly_movement_categories, local_one_week_probs, 1, local_two_week_probs, 2, sample_size=20)
    
print('Local one week model won ' + str(m1_wins) + ' times')
print('Local two week model won ' + str(m2_wins) + ' times')
# Out:
# Local one week model won 4751 times
# Local two week model won 4814 times

# %% [markdown]
# ## Composite 1 week model v.s. Composite 2 week model

# %%
all_two_week_trends, _, composite_one_week_probs, all_weekly_movement_categories = \
    get_trends_all_stocks(7, 2, movement_category_types, n_cats=4)

composite_two_week_probs = build_model_probabilities(all_weekly_movement_categories, all_two_week_trends, 2)

# %%
m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(weekly_movement_categories, composite_one_week_probs, 
                                                      1, composite_two_week_probs, 2, sample_size=20)

print('Composite one week model won ' + str(m1_wins) + ' times')
print('Composite two week model won ' + str(m2_wins) + ' times')
# Out:
# Composite one week model won 279 times
# Composite two week model won 9283 times

# %% [markdown]
# ## Local 2 week model v.s. Composite 2 week model
# Likely overfit

# %%
m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(weekly_movement_categories, local_two_week_probs, 
                                                      2, composite_two_week_probs, 2, sample_size=20)

print('Local two week model won ' + str(m1_wins) + ' times')
print('Composite two week model won ' + str(m2_wins) + ' times')
# Out:
# Local two week model won 9024 times
# Composite two week model won 823 times

# %% [markdown]
# ## Composite 2 week model v.s. Composite 3 week model

# %%
all_three_week_trends, _, _, _ = get_trends_all_stocks(7, 3, movement_category_types, n_cats=4)

composite_three_week_probs = build_model_probabilities(all_weekly_movement_categories, all_three_week_trends, 3)

# %%
m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(weekly_movement_categories, composite_two_week_probs, 
                                                      2, composite_three_week_probs, 3, sample_size=25)

print('Composite two week model won ' + str(m1_wins) + ' times')
print('Composite three week model won ' + str(m2_wins) + ' times')
# Out:
# Composite two week model won 2423 times
# Composite three week model won 7220 times

# %% [markdown]
# ## Composite 1 month model v.s. Composite 2 month model

# %%
all_two_month_trends, _, composite_one_month_probs, all_monthly_movement_categories = \
    get_trends_all_stocks(30, 2, movement_category_types, n_cats=4)

composite_two_month_probs = build_model_probabilities(all_monthly_movement_categories, all_two_month_trends, 2)

# %%
m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(monthly_movement_categories, composite_one_month_probs, 
                                                      1, composite_two_month_probs, 2, sample_size=10)

print('Composite one month model won ' + str(m1_wins) + ' times')
print('Composite two month model won ' + str(m2_wins) + ' times')
# Out:
# Composite one month model won 5930 times
# Composite two month model won 2256 times

# %% [markdown]
# ## Composite 2 month model v.s. Composite 3 month model

# %%
all_three_month_trends, _, _, _ = get_trends_all_stocks(30, 3, movement_category_types, n_cats=4)

composite_three_month_probs = build_model_probabilities(all_monthly_movement_categories, all_three_month_trends, 3)

# %%
m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(monthly_movement_categories, composite_two_month_probs, 
                                                      2, composite_three_month_probs, 3, sample_size=10)

print('Composite two month model won ' + str(m1_wins) + ' times')
print('Composite three month model won ' + str(m2_wins) + ' times')
# Out:
# Composite two month model won 1499 times
# Composite three month model won 7947 times

# %% [markdown]
# ## Composite 1 month model v.s. Composite 3 month model

# %%
m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(monthly_movement_categories, composite_one_month_probs, 
                                                      1, composite_three_month_probs, 3, sample_size=10)

print('Composite one month model won ' + str(m1_wins) + ' times')
print('Composite three month model won ' + str(m2_wins) + ' times')
# Out:
# Composite one month model won 1372 times
# Composite three month model won 8481 times

# %% [markdown]
# # All Stocks

# %%
g = glob.glob('stock_data/*.csv')

# %%
## Get composite weekly probabilities
all_two_week_trends, _, composite_one_week_probs, all_weekly_movement_categories = \
    get_trends_all_stocks(7, 2, movement_category_types, n_cats=4)
all_three_week_trends, _, _, _ = get_trends_all_stocks(7, 3, movement_category_types, n_cats=4)
composite_two_week_probs = build_model_probabilities(all_weekly_movement_categories, all_two_week_trends, 2)
composite_three_week_probs = build_model_probabilities(all_weekly_movement_categories, all_three_week_trends, 3)

## Get composite monthly probabilities
all_two_month_trends, _, composite_one_month_probs, all_monthly_movement_categories = \
    get_trends_all_stocks(30, 2, movement_category_types, n_cats=4)
all_three_month_trends, _, _, _ = get_trends_all_stocks(30, 3, movement_category_types, n_cats=4)
composite_two_month_probs = build_model_probabilities(all_monthly_movement_categories, all_two_month_trends, 2)
composite_three_month_probs = build_model_probabilities(all_monthly_movement_categories, all_three_month_trends, 3)

for filename in g:
    ticker = ticker_from_csv(filename)
    df = pd.DataFrame()
    df = df.from_csv(filename)
    weekly_movements = get_price_movements(df, period=7)
    weekly_movement_categories = categorize_movements(weekly_movements, n_cats=4)
    monthly_movements = get_price_movements(df, period=30)
    monthly_movement_categories = categorize_movements(monthly_movements, n_cats=4)

    two_week_movement_trends = get_trends(weekly_movement_categories, 2)
    three_week_movement_trends = get_trends(weekly_movement_categories, 3)
    two_month_movement_trends = get_trends(monthly_movement_categories, 2)
    three_month_movement_trends = get_trends(monthly_movement_categories, 3)

    local_two_week_probs = build_model_probabilities(weekly_movement_categories, two_week_movement_trends, 2)
    local_one_week_probs = build_model_probabilities(weekly_movement_categories, [], 1)
    local_two_month_probs = build_model_probabilities(monthly_movement_categories, two_month_movement_trends, 2)
    local_one_month_probs = build_model_probabilities(monthly_movement_categories, [], 1)
    
    print('=-=-=-=-=-=-=-=-=-=-=-=-=-=-=')
    print('             ' + ticker)
    print('=-=-=-=-=-=-=-=-=-=-=-=-=-=-=')
    print()
    
    print('--------------------------------------------------')
    print('Local 1 week model v.s. Local 2 week model')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = \
      random_sample_tests_m1_m2(weekly_movement_categories, local_one_week_probs, 1, local_two_week_probs, 2, sample_size=20)
    
    print('Local one week model won ' + str(m1_wins) + ' times')
    print('Local two week model won ' + str(m2_wins) + ' times')
    print()
    
    print('--------------------------------------------------')
    print('Composite 1 week model v.s. Composite 2 week model')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(weekly_movement_categories, composite_one_week_probs, 
                                                      1, composite_two_week_probs, 2, sample_size=20)

    print('Composite one week model won ' + str(m1_wins) + ' times')
    print('Composite two week model won ' + str(m2_wins) + ' times')
    print()
    
    print('--------------------------------------------------')
    print('Local 2 week model v.s. Composite 2 week model')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(weekly_movement_categories, local_two_week_probs, 
                                                      2, composite_two_week_probs, 2, sample_size=20)

    print('Local two week model won ' + str(m1_wins) + ' times')
    print('Composite two week model won ' + str(m2_wins) + ' times')
    print()
    
    print('--------------------------------------------------')
    print('Composite 2 week model v.s. Composite 3 week model')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(weekly_movement_categories, composite_two_week_probs, 
                                                      2, composite_three_week_probs, 3, sample_size=25)

    print('Composite two week model won ' + str(m1_wins) + ' times')
    print('Composite three week model won ' + str(m2_wins) + ' times')
    print()
    
    print('--------------------------------------------------')
    print('Composite 1 month model v.s. Composite 2 month model')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(monthly_movement_categories, composite_one_month_probs, 
                                                      1, composite_two_month_probs, 2, sample_size=10)

    print('Composite one month model won ' + str(m1_wins) + ' times')
    print('Composite two month model won ' + str(m2_wins) + ' times')
    print()

    print('--------------------------------------------------')
    print('Composite 2 month model v.s. Composite 3 month model')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(monthly_movement_categories, composite_two_month_probs, 
                                                      2, composite_three_month_probs, 3, sample_size=10)

    print('Composite two month model won ' + str(m1_wins) + ' times')
    print('Composite three month model won ' + str(m2_wins) + ' times')
    print()
    
    print('--------------------------------------------------')
    print('Composite 1 month model v.s. Composite 3 month model')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = random_sample_tests_m1_m2(monthly_movement_categories, composite_one_month_probs, 
                                                      1, composite_three_month_probs, 3, sample_size=10)

    print('Composite one month model won ' + str(m1_wins) + ' times')
    print('Composite three month model won ' + str(m2_wins) + ' times')
    print()
    
    print()
# Out:
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              BAC
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 852 times
# Local two week model won 8871 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 186 times
# Composite two week model won 9787 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 10000 times
# Composite two week model won 0 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 197 times
# Composite three week model won 9598 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 5617 times
# Composite two month model won 3537 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 394 times
# Composite three month model won 8490 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 162 times
# Composite three month model won 9044 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              NVDA
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 4814 times
# Local two week model won 4729 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 332 times
# Composite two week model won 9266 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 9110 times
# Composite two week model won 742 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 2457 times
# Composite three week model won 7196 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 6015 times
# Composite two month model won 2209 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 1477 times
# Composite three month model won 7986 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 1332 times
# Composite three month model won 8520 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              NKE
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 2263 times
# Local two week model won 7360 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 626 times
# Composite two week model won 8918 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 4289 times
# Composite two week model won 4844 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 1484 times
# Composite three week model won 7780 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 9052 times
# Composite two month model won 420 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 1471 times
# Composite three month model won 7815 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 1127 times
# Composite three month model won 7974 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              SBUX
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 937 times
# Local two week model won 8719 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 934 times
# Composite two week model won 9001 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 6743 times
# Composite two week model won 2897 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 1210 times
# Composite three week model won 8405 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 6475 times
# Composite two month model won 2026 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 1120 times
# Composite three month model won 8759 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 922 times
# Composite three month model won 8954 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              AMD
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 4293 times
# Local two week model won 5133 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 932 times
# Composite two week model won 8862 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 7895 times
# Composite two week model won 1604 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 1756 times
# Composite three week model won 7752 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 8184 times
# Composite two month model won 1366 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 2762 times
# Composite three month model won 6713 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 1625 times
# Composite three month model won 7841 times
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              MU
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 2041 times
# Local two week model won 7515 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 534 times
# Composite two week model won 9341 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 8825 times
# Composite two week model won 978 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 1715 times
# Composite three week model won 7735 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 8801 times
# Composite two month model won 1081 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 1404 times
# Composite three month model won 8035 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 1311 times
# Composite three month model won 8148 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              SPY
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 0 times
# Local two week model won 10000 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 428 times
# Composite two week model won 9555 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 8111 times
# Composite two week model won 1520 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 1565 times
# Composite three week model won 8160 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 4566 times
# Composite two month model won 3475 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 818 times
# Composite three month model won 9023 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 400 times
# Composite three month model won 9311 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              GOOG
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 4235 times
# Local two week model won 5443 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 1815 times
# Composite two week model won 7907 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 5512 times
# Composite two week model won 4313 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 928 times
# Composite three week model won 8668 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 10000 times
# Composite two month model won 0 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 4470 times
# Composite three month model won 5530 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 4383 times
# Composite three month model won 5617 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              TSLA
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 2478 times
# Local two week model won 7176 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 1946 times
# Composite two week model won 7819 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 2517 times
# Composite two week model won 6948 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 1292 times
# Composite three week model won 7864 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 9367 times
# Composite two month model won 412 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 4162 times
# Composite three month model won 4216 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 2844 times
# Composite three month model won 4787 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              FB
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 2904 times
# Local two week model won 6410 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 0 times
# Composite two week model won 10000 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 8183 times
# Composite two week model won 1425 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 2870 times
# Composite three week model won 6585 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 4327 times
# Composite two month model won 5673 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 576 times
# Composite three month model won 9133 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 617 times
# Composite three month model won 9102 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              INTC
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 1 week model v.s. Local 2 week model
# --------------------------------------------------
# Local one week model won 2654 times
# Local two week model won 6524 times
#
# --------------------------------------------------
# Composite 1 week model v.s. Composite 2 week model
# --------------------------------------------------
# Composite one week model won 2050 times
# Composite two week model won 7737 times
#
# --------------------------------------------------
# Local 2 week model v.s. Composite 2 week model
# --------------------------------------------------
# Local two week model won 9133 times
# Composite two week model won 735 times
#
# --------------------------------------------------
# Composite 2 week model v.s. Composite 3 week model
# --------------------------------------------------
# Composite two week model won 3393 times
# Composite three week model won 6021 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 2 month model
# --------------------------------------------------
# Composite one month model won 5826 times
# Composite two month model won 3339 times
#
# --------------------------------------------------
# Composite 2 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite two month model won 1819 times
# Composite three month model won 7473 times
#
# --------------------------------------------------
# Composite 1 month model v.s. Composite 3 month model
# --------------------------------------------------
# Composite one month model won 2040 times
# Composite three month model won 7679 times

# %% [markdown]
# # Volume Models

# %%
df = pd.DataFrame()
df = df.from_csv('stock_data/nvda.csv')

daily_rel_volumes_25 = get_relative_volume(df, relative_period=25)
daily_rel_volumes_50 = get_relative_volume(df, relative_period=50)
daily_rel_volume_categories_25 = categorize_volumes(daily_rel_volumes_25)
daily_rel_volume_categories_50 = categorize_volumes(daily_rel_volumes_50)

daily_movements = get_price_movements(df)
daily_movement_categories = categorize_movements(daily_movements, n_cats=4)

# %%
local_two_day_vol_trends_25 = get_two_day_volume_trends(daily_rel_volume_categories_25, daily_movement_categories)
local_two_day_vol_trends_50 = get_two_day_volume_trends(daily_rel_volume_categories_50, daily_movement_categories)

# %%
local_two_day_probs_25 = build_model_probabilities(daily_movement_categories, local_two_day_vol_trends_25, 2, 
                                               previous_category_types=['vl', 'l', 'h', 'vh'])
local_two_day_probs_50 = build_model_probabilities(daily_movement_categories, local_two_day_vol_trends_50, 2, 
                                               previous_category_types=['vl', 'l', 'h', 'vh'])

# %% [markdown]
# ## Local 2 day Relative Volume Model: RP=25 v.s. RP=50

# %%
m1_wins, m2_wins, n_draws = \
    random_sample_tests_m1_m2(daily_movement_categories, local_two_day_probs_25, 2, local_two_day_probs_50, 2)
    
print('RP=25 won ' + str(m1_wins) + ' times')
print('RP=50 won ' + str(m2_wins) + ' times')
# Out:
# RP=25 won 7400 times
# RP=50 won 2375 times

# %% [markdown]
# #### All stocks -- Local
# The sweet spot seems to be about a 20 day relative window

# %%
for filename in g:
    ticker = ticker_from_csv(filename)
    df = pd.DataFrame()
    df = df.from_csv(filename)
    
    daily_rel_volumes_10 = get_relative_volume(df, relative_period=10)
    daily_rel_volumes_20 = get_relative_volume(df, relative_period=20)
    daily_rel_volumes_30 = get_relative_volume(df, relative_period=30)
    daily_rel_volumes_40 = get_relative_volume(df, relative_period=40)
    daily_rel_volumes_50 = get_relative_volume(df, relative_period=50)
    daily_rel_volume_categories_10 = categorize_volumes(daily_rel_volumes_10)
    daily_rel_volume_categories_20 = categorize_volumes(daily_rel_volumes_20)
    daily_rel_volume_categories_30 = categorize_volumes(daily_rel_volumes_30)
    daily_rel_volume_categories_40 = categorize_volumes(daily_rel_volumes_40)
    daily_rel_volume_categories_50 = categorize_volumes(daily_rel_volumes_50)
    
    daily_movements = get_price_movements(df)
    daily_movement_categories = categorize_movements(daily_movements, n_cats=4)
    
    local_two_day_vol_trends_10 = get_two_day_volume_trends(daily_rel_volume_categories_10, daily_movement_categories)
    local_two_day_vol_trends_20 = get_two_day_volume_trends(daily_rel_volume_categories_20, daily_movement_categories)
    local_two_day_vol_trends_30 = get_two_day_volume_trends(daily_rel_volume_categories_30, daily_movement_categories)
    local_two_day_vol_trends_40 = get_two_day_volume_trends(daily_rel_volume_categories_40, daily_movement_categories)
    local_two_day_vol_trends_50 = get_two_day_volume_trends(daily_rel_volume_categories_50, daily_movement_categories)
    
    local_two_day_probs_10 = build_model_probabilities(daily_movement_categories, local_two_day_vol_trends_10, 2, 
                                               previous_category_types=['vl', 'l', 'h', 'vh'])
    local_two_day_probs_20 = build_model_probabilities(daily_movement_categories, local_two_day_vol_trends_20, 2, 
                                               previous_category_types=['vl', 'l', 'h', 'vh'])
    local_two_day_probs_30 = build_model_probabilities(daily_movement_categories, local_two_day_vol_trends_30, 2, 
                                               previous_category_types=['vl', 'l', 'h', 'vh'])
    local_two_day_probs_40 = build_model_probabilities(daily_movement_categories, local_two_day_vol_trends_40, 2, 
                                               previous_category_types=['vl', 'l', 'h', 'vh'])
    local_two_day_probs_50 = build_model_probabilities(daily_movement_categories, local_two_day_vol_trends_50, 2, 
                                               previous_category_types=['vl', 'l', 'h', 'vh'])
    
    m1_wins, m2_wins, n_draws = \
    random_sample_tests_m1_m2(daily_movement_categories, local_two_day_probs_25, 2, local_two_day_probs_50, 2)
    
    print('=-=-=-=-=-=-=-=-=-=-=-=-=-=-=')
    print('             ' + ticker)
    print('=-=-=-=-=-=-=-=-=-=-=-=-=-=-=')
    print()
    print('--------------------------------------------------')
    print('Local 2 day Relative Volume Model: RP=10 v.s. RP=20')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = \
    random_sample_tests_m1_m2(daily_movement_categories, local_two_day_probs_10, 2, local_two_day_probs_20, 2)
    print('RP=10 won ' + str(m1_wins) + ' times')
    print('RP=20 won ' + str(m2_wins) + ' times')
    print()
    print('--------------------------------------------------')
    print('Local 2 day Relative Volume Model: RP=20 v.s. RP=30')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = \
    random_sample_tests_m1_m2(daily_movement_categories, local_two_day_probs_20, 2, local_two_day_probs_30, 2)
    print('RP=20 won ' + str(m1_wins) + ' times')
    print('RP=30 won ' + str(m2_wins) + ' times')
    print()
    print('--------------------------------------------------')
    print('Local 2 day Relative Volume Model: RP=30 v.s. RP=40')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = \
    random_sample_tests_m1_m2(daily_movement_categories, local_two_day_probs_30, 2, local_two_day_probs_40, 2)
    print('RP=30 won ' + str(m1_wins) + ' times')
    print('RP=40 won ' + str(m2_wins) + ' times')
    print()
    print('--------------------------------------------------')
    print('Local 2 day Relative Volume Model: RP=40 v.s. RP=50')
    print('--------------------------------------------------')
    m1_wins, m2_wins, n_draws = \
    random_sample_tests_m1_m2(daily_movement_categories, local_two_day_probs_40, 2, local_two_day_probs_50, 2)
    print('RP=40 won ' + str(m1_wins) + ' times')
    print('RP=50 won ' + str(m2_wins) + ' times')
    print()
    print()
# Out:
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              BAC
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 8041 times
# RP=20 won 1816 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 9364 times
# RP=30 won 567 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 6873 times
# RP=40 won 2822 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 1950 times
# RP=50 won 7762 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              NVDA
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 1729 times
# RP=20 won 8063 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 9398 times
# RP=30 won 567 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 7395 times
# RP=40 won 2113 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 6252 times
# RP=50 won 3257 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              NKE
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 4764 times
# RP=20 won 4784 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 7013 times
# RP=30 won 2622 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 6658 times
# RP=40 won 3129 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 5133 times
# RP=50 won 4356 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              SBUX
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 8214 times
# RP=20 won 1619 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 3984 times
# RP=30 won 5772 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 651 times
# RP=40 won 9275 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 8505 times
# RP=50 won 1385 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              AMD
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 975 times
# RP=20 won 8911 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 8129 times
# RP=30 won 1518 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 10000 times
# RP=40 won 0 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 7430 times
# RP=50 won 2257 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              MU
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 619 times
# RP=20 won 9335 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 336 times
# RP=30 won 9553 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 7198 times
# RP=40 won 2510 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 898 times
# RP=50 won 8871 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              SPY
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 643 times
# RP=20 won 9223 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 8744 times
# RP=30 won 1098 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 2213 times
# RP=40 won 7626 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 5810 times
# RP=50 won 3833 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              GOOG
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 7793 times
# RP=20 won 1779 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 5610 times
# RP=30 won 4116 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 6559 times
# RP=40 won 2905 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 2475 times
# RP=50 won 6950 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              TSLA
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 1814 times
# RP=20 won 7797 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 5514 times
# RP=30 won 4084 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 8318 times
# RP=40 won 1375 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 1817 times
# RP=50 won 7872 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              FB
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 1631 times
# RP=20 won 8166 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 7324 times
# RP=30 won 2460 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 1917 times
# RP=40 won 7964 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 877 times
# RP=50 won 9040 times
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#              INTC
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=10 v.s. RP=20
# --------------------------------------------------
# RP=10 won 2320 times
# RP=20 won 7545 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=20 v.s. RP=30
# --------------------------------------------------
# RP=20 won 8648 times
# RP=30 won 1208 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=30 v.s. RP=40
# --------------------------------------------------
# RP=30 won 895 times
# RP=40 won 8914 times
#
# --------------------------------------------------
# Local 2 day Relative Volume Model: RP=40 v.s. RP=50
# --------------------------------------------------
# RP=40 won 9358 times
# RP=50 won 597 times

# %% [markdown]
# ## Local 2 day Relative Volume Model (RP=20) v.s. Composite 2 day Relative Volume Model
